# %% [markdown]
# ## Pandas demo from Jake Reback
# see https://github.com/jreback/PyDataNYC2015 or http://pandas.pydata.org/pandas-docs/version/0.17.1/style.html#Table-Styles

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import seaborn as sns
pd.options.display.max_rows=12
pd.options.display.width=80

# read a csv
df = pd.read_csv('~/seaborn-data/iris.csv',index_col=False)
# adjust column names
df.columns = df.columns.str.replace('\s+','_').str.lower()
# in pandas 0.17.1 and more : sample and style ... 
def color_negative_red(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'red' if   (isinstance(val, (int,   float)) and val < 3) else 'black'
    return 'color: %s' % color

def highlight_max(s):
    '''
    highlight the maximum in a Series
    '''
    is_max = s == s.max()
    return ['background-color: yellow' if v else '' for v in is_max]

cm = sns.light_palette("green", as_cmap=True)

(df
   .sample (n=7)
   .style
   .applymap(color_negative_red, subset=pd.IndexSlice[['sepal_width', 'petal_width']])
   .bar(subset=['sepal_length', 'petal_length'], color='#7F7FFF')
   .background_gradient(subset=['sepal_width', 'petal_width'], cmap=cm)
   .apply(highlight_max)
   .highlight_null(null_color='red')
)
# Out:
# <style  type="text/css" >
#     #T_61631086_0f14_11e9_a200_3464a9396b48row0_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 24.0%, transparent 0%);
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row0_col1 {
#             color:  black;
#             background-color:  #008000;
#             background-color:  yellow;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row0_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 8.5%, transparent 0%);
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row0_col3 {
#             color:  red;
#             background-color:  #d8f8d8;
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row1_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 96.0%, transparent 0%);
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row1_col1 {
#             color:  red;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row1_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 100.0%, transparent 0%);
#             background-color:  yellow;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row1_col3 {
#             color:  red;
#             background-color:  #008000;
#             background-color:  yellow;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row1_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row2_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 72.0%, transparent 0%);
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row2_col1 {
#             color:  black;
#             background-color:  #269526;
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row2_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 74.5%, transparent 0%);
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row2_col3 {
#             color:  red;
#             background-color:  #369e36;
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row3_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 80.0%, transparent 0%);
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row3_col1 {
#             color:  red;
#             background-color:  #73c073;
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row3_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 85.1%, transparent 0%);
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row3_col3 {
#             color:  red;
#             background-color:  #289628;
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row3_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row4_col0 {
#             width:  10em;
#              height:  80%;
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row4_col1 {
#             color:  black;
#             background-color:  #269526;
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row4_col2 {
#             width:  10em;
#              height:  80%;
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row4_col3 {
#             color:  red;
#             background-color:  #e5ffe5;
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row5_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 80.0%, transparent 0%);
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row5_col1 {
#             color:  red;
#             background-color:  #4daa4d;
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row5_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 95.7%, transparent 0%);
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row5_col3 {
#             color:  red;
#             background-color:  #008000;
#             background-color:  yellow;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row5_col4 {
#             background-color:  yellow;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row6_col0 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 100.0%, transparent 0%);
#             background-color:  yellow;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row6_col1 {
#             color:  red;
#             background-color:  #73c073;
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row6_col2 {
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#7F7FFF 78.7%, transparent 0%);
#             : ;
#             : ;
#         }    #T_61631086_0f14_11e9_a200_3464a9396b48row6_col3 {
#             color:  red;
#             background-color:  #369e36;
#             : ;
#             : ;
#         }</style>
# <table id="T_61631086_0f14_11e9_a200_3464a9396b48" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >sepal_length</th>
#         <th class="col_heading level0 col1" >sepal_width</th>
#         <th class="col_heading level0 col2" >petal_length</th>
#         <th class="col_heading level0 col3" >petal_width</th>
#         <th class="col_heading level0 col4" >species</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_61631086_0f14_11e9_a200_3464a9396b48level0_row0" class="row_heading level0 row0" >34</th>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row0_col0" class="data row0 col0" >4.9</td>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row0_col1" class="data row0 col1" >3.1</td>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row0_col2" class="data row0 col2" >1.5</td>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row0_col3" class="data row0 col3" >0.2</td>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row0_col4" class="data row0 col4" >setosa</td>
#     </tr>    <tr>
#         <th id="T_61631086_0f14_11e9_a200_3464a9396b48level0_row1" class="row_heading level0 row1" >108</th>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row1_col0" class="data row1 col0" >6.7</td>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row1_col1" class="data row1 col1" >2.5</td>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row1_col2" class="data row1 col2" >5.8</td>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row1_col3" class="data row1 col3" >1.8</td>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row1_col4" class="data row1 col4" >virginica</td>
#     </tr>    <tr>
#         <th id="T_61631086_0f14_11e9_a200_3464a9396b48level0_row2" class="row_heading level0 row2" >91</th>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row2_col0" class="data row2 col0" >6.1</td>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row2_col1" class="data row2 col1" >3</td>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row2_col2" class="data row2 col2" >4.6</td>
#         <td id="T_61631086_0f14_11e9_a200_3464a9396b48row2_col3" class="dat

# %%
# assign = define new temporary columns (like 'mutate' in R language)
(df
   .query('sepal_length > 5')
   .assign(sepal_ratio = lambda x: x.sepal_width / x.sepal_length,
           petal_ratio = lambda x: x.petal_width / x.petal_length)
   .plot
   .scatter(x='sepal_ratio', y='petal_ratio', figsize=(8,4))
)

# %%
# pipe = like '%>%' in R language
(df
   .query('sepal_length > 5')
   .assign(sepal_ratio = lambda x: x.sepal_width / x.sepal_length,
           petal_ratio = lambda x: x.petal_width / x.petal_length)
   .pipe(sns.pairplot, hue='species', size=1.5)
)

# %%
# Pandas interactive
import pandas as pd
import numpy as np

# create a df with random datas
np.random.seed(24)
df = pd.DataFrame({'A': np.linspace(1, 10, 10)})
df = pd.concat([df, pd.DataFrame(np.random.randn(10, 4), columns=list('BCDE'))],
               axis=1)
df.iloc[0, 2] = np.nan

# interactive
from IPython.html import widgets
@widgets.interact
def f(h_neg=(0, 359, 1), h_pos=(0, 359), s=(0., 99.9), l=(0., 99.9)):
    return (df
             .style
             .background_gradient(
                cmap=sns.palettes.diverging_palette(
                     h_neg=h_neg, h_pos=h_pos, s=s, l=l, as_cmap=True)
             ).highlight_null()
           )

# %%
from IPython.display import HTML

def hover(hover_color="#ff0f99"):
    return dict(selector="tr:hover",
                props=[("background-color", "%s" % hover_color)])

styles = [
    hover(),
    dict(selector="th", props=[("font-size", "150%"),
                               ("text-align", "center")]),
    dict(selector="caption", props=[("caption-side", "bottom")])
]
html = (df.style.set_table_styles(styles)
          .set_caption("Hover to highlight."))
html

# %% [markdown]
# ## Usefull links
#
# ### Beginners Training Video: ["Brandon Rhodes - Pandas From The Ground Up - PyCon 2015 "](https://www.youtube.com/watch?v=5JnMutdy6Fw)
#
# ### Pandas [API reference](http://pandas.pydata.org/pandas-docs/stable/api.html)
